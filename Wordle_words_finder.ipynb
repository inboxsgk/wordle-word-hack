Apace
Apart
Aptly
Arear
Aside
Askew
Awful
Badly
Bally
Below
Canny
Cheap
Clean
Clear
Coyly
Daily
Dimly
Dirty
Ditto
Drily
Dryly
Dully
Early
Extra
False
Fatly
Feyly
First
Fitly
Forte
Forth
Fresh
Fully
Funny
Gaily
Gayly
Godly
Great
Haply
Heavy
Hella
Hence
Hotly
Icily
Infra
Jildi
Jolly
Laxly
Lento
Light
Lowly
Madly
Maybe
Never
Newly
Nobly
Oddly
Often
Other
Ought
Party
Piano
Plain
Plonk
Plumb
Prior
Queer
Quick
Quite
Ramen
Rapid
Redly
Right
Rough
Round
Sadly
Secus
Selly
Sharp
Sheer
Shily
Short
Shyly
Silly
Since
Sleek
Slyly
Small
Sound
Spang
Srsly
Stark
Still
Stone
Stour
Super
Tally
Tanto
There
Thick
Tight
Today
Tomoz
Truly
Twice
Under
Utter
Verry
Wanly
Wetly
Where
Wrong
Wryly
Abaft
Aboon
About
Above
Adown
Afore
After
Along
Aloof
Among
Below
Circa
Cross
Furth
Minus
Neath
Round
Since
Spite
Under
Until
Aargh
Adieu
Adios
Alack
Aloha
Avast
Bakaw
Basta
Begad
Bless
Blige
Brava
Bravo
Bring
Chook
Damme
Dildo
Ditto
Frick
Fudge
Golly
Gratz
Hallo
Hasta
Havoc
Hella
Hello
Howay
Howdy
Hullo
Huzza
Jesus
Kapow
Loose
Lordy
Marry
Mercy
Night
Plonk
Psych
Quite
Salve
Skoal
Sniff
Sooey
There
Thiam
Thwap
Tough
Twirp
Viola
Vivat
Wacko
Wahey
Whist
Wilma
Wirra
Woops
Wowie
Yecch
Yeeha
Yeesh
Yowch
Zowie""";

x = x.lower();
x = x.split("\n");
x = x[::-1]
print(len(x));
# Out:
# 657

# %%
c = []
ln = {}
for i in x:
  cur = []
  for j in i:
    cur.append(j)
  print(cur)
  for j in i:
    if j not in c:
      c.append(j)
      ln[j] = 1
    elif j in c:
      if cur.count(j)==1:
        ln[j] += 1

# %% [markdown]
# ## Count

# %%
ln = dict(sorted(ln.items(), key=lambda item: item[1]))
t=0
for i in ln:
  print(i,"-",ln[i])
  t+=ln[i]
print(t)
print(len(ln))
# Out:
# z - 5
# x - 8
# q - 9
# j - 11
# k - 40
# v - 41
# b - 57
# m - 60
# f - 63
# w - 64
# g - 73
# p - 81
# y - 94
# d - 97
# c - 108
# u - 116
# n - 138
# s - 148
# h - 154
# l - 168
# i - 174
# o - 189
# t - 204
# r - 221
# e - 260
# a - 272
# 2855
# 26

# %% [markdown]
# ## Calculating Probability of letter appearing in a given word

# %%
pr = {}
for i in ln:
  pr[i] = (ln[i]/t)
  print(i, " - ", pr[i])
# Out:
# z  -  0.0017513134851138354
# x  -  0.0028021015761821367
# q  -  0.0031523642732049035
# j  -  0.003852889667250438
# k  -  0.014010507880910683
# v  -  0.01436077057793345
# b  -  0.019964973730297722
# m  -  0.021015761821366025
# f  -  0.022066549912434327
# w  -  0.022416812609457094
# g  -  0.025569176882661998
# p  -  0.028371278458844133
# y  -  0.0329246935201401
# d  -  0.033975481611208405
# c  -  0.037828371278458846
# u  -  0.040630472854640984
# n  -  0.04833625218914186
# s  -  0.05183887915936953
# h  -  0.05394045534150613
# l  -  0.05884413309982487
# i  -  0.06094570928196147
# o  -  0.06619964973730298
# t  -  0.07145359019264448
# r  -  0.07740805604203152
# e  -  0.09106830122591944
# a  -  0.09527145359019265

# %%
for i in ln:
  print(i,"-",ln[i])
# Out:
# z - 5
# x - 8
# q - 9
# j - 11
# k - 40
# v - 41
# b - 57
# m - 60
# f - 63
# w - 64
# g - 73
# p - 81
# y - 94
# d - 97
# c - 108
# u - 116
# n - 138
# s - 148
# h - 154
# l - 168
# i - 174
# o - 189
# t - 204
# r - 221
# e - 260
# a - 272

# %% [markdown]
# ## Generating Probability for every word in dataset based on letters frequency

# %%
scores={}
for i in x:
  cur = 0
  for j in i:
    cur += pr[j]
  scores[i]=cur
  #print(i, " - ", scores[i])

# %%
scores = dict(sorted(scores.items(), key=lambda item: item[1]))
l_final = []
for i in scores:
  print(i," - ", scores[i])
  l_final.append(i)
# Out:
# quick  -  0.15656742556917688
# plumb  -  0.16882661996497372
# lucky  -  0.18423817863397549
# funny  -  0.19229422066549914
# huzza  -  0.19334500875656743
# judge  -  0.19509632224168127
# rugby  -  0.19649737302977233
# block  -  0.1968476357267951
# climb  -  0.19859894921190896
# imply  -  0.2021015761821366
# psych  -  0.20490367775831875
# sniff  -  0.2052539404553415
# dimly  -  0.20770577933450088
# stuff  -  0.20805604203152367
# amuck  -  0.2087565674255692
# howdy  -  0.20945709281961472
# frick  -  0.21225919439579682
# music  -  0.21225919439579685
# yowch  -  0.21330998248686514
# fully  -  0.21330998248686514
# fudge  -  0.21330998248686517
# young  -  0.21366024518388793
# build  -  0.21436077057793346
# clock  -  0.21471103327495622
# plonk  -  0.21576182136602454
# godly  -  0.21751313485113835
# pound  -  0.21751313485113838
# jildi  -  0.21856392294220667
# focus  -  0.21856392294220667
# jolly  -  0.22066549912434325
# blind  -  0.22206654991243435
# ...

# %%
l_final = l_final[::-1]

# %%
for i in l_final:
  print(i)
# Out:
# arear
# treat
# alter
# error
# heart
# earth
# there
# aware
# taste
# state
# agree
# enter
# arise
# raise
# ratio
# learn
# share
# ahead
# aloha
# trade
# apart
# hasta
# start
# laura
# sheer
# steel
# yeeha
# trial
# total
# great
# clear
# neath
# other
# alone
# sheet
# peter
# refer
# store
# hella
# water
# after
# layer
# reach
# early
# aline
# title
# train
# tanto
# afore
# utter
# leave
# terry
# teach
# rural
# large
# apace
# aargh
# route
# outer
# order
# death
# plate
# spare
# peace
# hotel
# horse
# ideal
# extra
# metal
# anger
# range
# table
# acute
# lento
# where
# agape
# stage
# scale
# sense
# loose
# steep
# basta
# radio
# green
# wirra
# aside
# ramen
# hallo
# thame
# harsh
# waste
# agent
# clean
# royal
# steam
# ready
# argue
# legal
# stone
# hello
# theme
# tower
# alife
# forte
# avast
# sweet
# agone
# inner
# thine
# serve
# chair
# relax
# again
# score
# award
# write
# drama
# coast
# cream
# trend
# hence
# never
# panel
# plane
# adieu
# ...

# %%
lett = []
u_words = []
print("Done")
# Out:
# Done

# %%
for i in l_final:
  b = 0
  c = []
  for j in i:
    if j not in c:
      c.append(j)
    elif j in c:
      b=1
      break
  if (b==1):
    continue
  for j in i:
    if j in lett:
      b+=1
      break
  if (b==1):
    continue
  else :
    print("Found: ", i)
    u_words.append(i)
    for j in i:
      lett.append(j)
# Out:
# Found:  alter
# Found:  sound

# %%
print(lett)
print(len(u_words))
print(u_words)
# Out:
# ['u', 'p', 's', 'e', 't', 'r', 'o', 'y', 'a', 'l']
# 5
# ['zowie', 'psych', 'urban', 'upset', 'royal']

# %%
test = ['abuse', 'child', 'front', 'alter', 'sound', 'chirp']
for i in test:
  cur = 0
  for j in i:
    cur += pr[j]
  print(i, " - ", cur)
# Out:
# abuse  -  0.2987740805604203
# child  -  0.2455341506129597
# front  -  0.28546409807355516
# alter  -  0.39404553415061294
# sound  -  0.24098073555166377
# chirp  -  0.2584938704028021
